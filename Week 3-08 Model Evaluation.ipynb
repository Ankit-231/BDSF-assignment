# %% [markdown]
# ## Phase A EDA

# %%
# note: second part of assignment is after Phase A
# note: third part of assignment is after Phase B

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# #### 1) Collecting data

# %%
df = pd.read_csv("housing_prices_assignment.csv")

# %% [markdown]
# #### 2) Understanding data

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
a = 0
b = 0
for i in df['Alley'].isna():
    if i == True:
        a += 1
    else:
        b += 1
print(f'null = {a}')
print(f'not null = {b}')
# Out:
# null = 1369
# not null = 91

# %%
a = 0
b = 0
for i in df['MiscFeature'].isna():
    if i == True:
        a += 1
    else:
        b += 1
print(f'null = {a}')
print(f'not null = {b}')
# Out:
# null = 1406
# not null = 54

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df[['LotShape', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
       'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
       'MasVnrArea', 'ExterQual']].describe()
# Out:
#        OverallQual  OverallCond    YearBuilt  YearRemodAdd   MasVnrArea
# count  1460.000000  1460.000000  1460.000000   1460.000000  1452.000000
# mean      6.099315     5.575342  1971.267808   1984.865753   103.685262
# std       1.382997     1.112799    30.202904     20.645407   181.066207
# min       1.000000     1.000000  1872.000000   1950.000000     0.000000
# 25%       5.000000     5.000000  1954.000000   1967.000000     0.000000
# 50%       6.000000     5.000000  1973.000000   1994.000000     0.000000
# 75%       7.000000     6.000000  2000.000000   2004.000000   166.000000
# max      10.000000     9.000000  2010.000000   2010.000000  1600.000000

# %% [markdown]
# #### 3) Cleaning data

# %%
integer_columns = df.select_dtypes(include=['int64']).columns
float_columns = df.select_dtypes(include=['float64']).columns
object_columns = df.select_dtypes(include=['object']).columns
int_fl_columns = df.select_dtypes(include=['int64', 'float64']).columns

# %%
dfonlynum = df[int_fl_columns]

# %%
dfonlynum
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %%
dfonlynum_cl = dfonlynum.dropna()

# %%
dfonlynum_cl.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
dfonlynum_cl.OverallQual
# Out:
# 0       7
# 1       6
# 2       7
# 3       7
# 4       8
#        ..
# 1455    6
# 1456    6
# 1457    7
# 1458    5
# 1459    5
# Name: OverallQual, Length: 1121, dtype: int64

# %% [markdown]
# ### Statistical Analysis

# %%
dfonlynum_cl.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1121.000000  1121.000000  1121.000000    1121.000000  1121.000000
# mean    726.842105    56.146298    70.665477   10122.956289     6.212310
# std     420.769012    41.772684    24.266812    8129.302641     1.380822
# min       1.000000    20.000000    21.000000    1300.000000     2.000000
# 25%     364.000000    20.000000    60.000000    7590.000000     5.000000
# 50%     725.000000    50.000000    70.000000    9416.000000     6.000000
# 75%    1091.000000    70.000000    80.000000   11361.000000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1121.000000  1121.000000   1121.000000  1121.000000  1121.000000
# mean      5.561106  1972.264942   1985.683318   108.487957   438.399643
# std       1.068236    30.967730     21.025974   189.500966   468.385038
# ...

# %% [markdown]
# ##### 150k plus usd houses?

# %% [markdown]
# # Phase B (AI Model)

# %%
# predict price of house with the given set of features

# %%
dfonlynum_cl.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
dfonlynum_cl
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %%
pd.set_option('max_columns', None)

# %%
features = ['SalePrice', 'LotFrontage', 'LotArea', 'OverallQual',
            'OverallCond', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 
            '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 
            'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
       'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
       'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
       'MiscVal', 'MoSold', 'YrSold']
X = dfonlynum_cl[features]
y = dfonlynum_cl['SalePrice']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=30)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()

model.fit(X_train, y_train)

print('Accuracy of Logistic regression classifier on training set: {:.2f}'.format(model.score(X_train, y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.2f}'.format(model.score(X_test, y_test)))
# Out:
# Accuracy of Logistic regression classifier on training set: 1.00
# Accuracy of Logistic regression classifier on test set: 1.00

# %%
# newInputs = list(dfonlynum_cl.loc[80,features]) 
newInputs = [875411.0, 90.0, 13456.0, 7.0, 6.0, 785.0, 457.0, 0.0, 1148.0, 980.0, 0.0,
            2145.0, 0.0, 0.0, 2.0, 1.0, 4.0, 1.0, 8.0, 1.0, 1968.0, 1.0, 567.0, 0.0, 70.0,
            0.0, 0.0, 245.0, 0.0, 0.0, 5.0, 2045.0]
Xnew = [newInputs]

# make a prediction
ynew = model.predict(Xnew)
print("X=%s, Predicted=%s" % (Xnew[0], ynew[0]))
# Out:
# X=[875411.0, 90.0, 13456.0, 7.0, 6.0, 785.0, 457.0, 0.0, 1148.0, 980.0, 0.0, 2145.0, 0.0, 0.0, 2.0, 1.0, 4.0, 1.0, 8.0, 1.0, 1968.0, 1.0, 567.0, 0.0, 70.0, 0.0, 0.0, 245.0, 0.0, 0.0, 5.0, 2045.0], Predicted=616284.78

# %%
# newInputs = list(dfonlynum_cl.loc[80,features]) 

Xnew = [newInputs]

# make a prediction
ynew = model.predict(Xnew)
print("X=%s, Predicted=%s" % (Xnew[0], ynew[0]))
# Out:
# X=[875411.0, 90.0, 13456.0, 7.0, 6.0, 785.0, 457.0, 0.0, 1148.0, 980.0, 0.0, 2145.0, 0.0, 0.0, 2.0, 1.0, 4.0, 1.0, 8.0, 1.0, 1968.0, 1.0, 567.0, 0.0, 70.0, 0.0, 0.0, 245.0, 0.0, 0.0, 5.0, 2045.0], Predicted=616284.78

# %%
dfonlynum_cl.loc[80]
# Out:
# Id                   81.0
# MSSubClass           60.0
# LotFrontage         100.0
# LotArea           13000.0
# OverallQual           6.0
# OverallCond           6.0
# YearBuilt          1968.0
# YearRemodAdd       1968.0
# MasVnrArea          576.0
# BsmtFinSF1          448.0
# BsmtFinSF2            0.0
# BsmtUnfSF           448.0
# TotalBsmtSF         896.0
# 1stFlrSF           1182.0
# 2ndFlrSF            960.0
# LowQualFinSF          0.0
# GrLivArea          2142.0
# BsmtFullBath          0.0
# BsmtHalfBath          0.0
# FullBath              2.0
# HalfBath              1.0
# BedroomAbvGr          4.0
# KitchenAbvGr          1.0
# TotRmsAbvGrd          8.0
# Fireplaces            1.0
# GarageYrBlt        1968.0
# GarageCars            1.0
# GarageArea          509.0
# WoodDeckSF            0.0
# OpenPorchSF          72.0
# EnclosedPorch         0.0
# 3SsnPorch             0.0
# ScreenPorch         252.0
# PoolArea              0.0
# MiscVal               0.0
# ...

# %%
mean_absolute_error([193500.0], [613221.84])
# Out:
# 419721.83999999997

# %%
y_pred = model.predict(X_test)
y_pred = pd.Series(y_pred)

# %%
y_pred
# Out:
# 0      120084.50
# 1      151972.36
# 2       58776.28
# 3      120146.00
# 4      124496.00
#          ...
# 332     79565.00
# 333    124972.00
# 334    132934.00
# 335    180581.00
# 336     97335.50
# Length: 337, dtype: float64

# %% [markdown]
# # Phase C (Model Evaluation)

# %%
# calculating mean absolute error
from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error",mean_absolute_error(y_test,y_pred))
# Out:
# Mean Absolute Error 436.32940652819013

# %%
# calculating mean squared error
from sklearn.metrics import mean_squared_error
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 4421313.57864125

# %%
# calculating Root Mean Squared Error
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 2102.691983777284

# %%
# note: keeping random_state=30 seems to be resulting in less MAE
